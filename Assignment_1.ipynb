# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# %%
max_features = 10000
max_len = 500
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
def create_model(model_type):
    model = Sequential()
    model.add(Embedding(max_features, 32, input_length=max_len))
    if model_type == 'LSTM':
       model.add(LSTM(32))
    elif model_type == 'GRU':
      model.add(GRU(32))
    elif model_type == 'RNN':
          model.add(SimpleRNN(32))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model_types = ['LSTM', 'GRU', 'RNN']
histories = []

# %%
plt.figure(figsize=(10, 6))

# %%
for model_type in model_types:
  model = create_model(model_type)
  history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2, verbose=1)
  plt.plot(history.history['val_accuracy'], label=f'{model_type} Validation Accuracy')
# Out:
# Epoch 1/5
# 157/157 [==============================] - 62s 360ms/step - loss: 0.5908 - accuracy: 0.7106 - val_loss: 0.4020 - val_accuracy: 0.8310
# Epoch 2/5
# 157/157 [==============================] - 58s 370ms/step - loss: 0.2984 - accuracy: 0.8831 - val_loss: 0.2981 - val_accuracy: 0.8818
# Epoch 3/5
# 157/157 [==============================] - 58s 368ms/step - loss: 0.2112 - accuracy: 0.9232 - val_loss: 0.3194 - val_accuracy: 0.8712
# Epoch 4/5
# 157/157 [==============================] - 59s 375ms/step - loss: 0.1779 - accuracy: 0.9368 - val_loss: 0.3084 - val_accuracy: 0.8802
# Epoch 5/5
# 157/157 [==============================] - 59s 377ms/step - loss: 0.1211 - accuracy: 0.9614 - val_loss: 0.3190 - val_accuracy: 0.8806
# Epoch 1/5
# 157/157 [==============================] - 62s 376ms/step - loss: 0.5737 - accuracy: 0.6930 - val_loss: 0.3803 - val_accuracy: 0.8378
# Epoch 2/5
# 157/157 [==============================] - 59s 373ms/step - loss: 0.2964 - accuracy: 0.8785 - val_loss: 0.3314 - val_accuracy: 0.8648
# Epoch 3/5
# 157/157 [==============================] - 59s 377ms/step - loss: 0.2128 - accuracy: 0.9193 - val_loss: 0.3461 - val_accuracy: 0.8696
# Epoch 4/5
# 157/157 [==============================] - 56s 355ms/step - loss: 0.1735 - accuracy: 0.9372 - val_loss: 0.3521 - val_accuracy: 0.8642
# Epoch 5/5
# 157/157 [==============================] - 57s 365ms/step - loss: 0.1377 - accuracy: 0.9538 - val_loss: 0.3732 - val_accuracy: 0.8572
# Epoch 1/5
# 157/157 [==============================] - 29s 177ms/step - loss: 0.6869 - accuracy: 0.5411 - val_loss: 0.6735 - val_accuracy: 0.5840
# Epoch 2/5
# 157/157 [==============================] - 30s 188ms/step - loss: 0.5785 - accuracy: 0.7261 - val_loss: 0.5616 - val_accuracy: 0.7046
# Epoch 3/5
# 157/157 [==============================] - 28s 179ms/step - loss: 0.2615 - accuracy: 0.9020 - val_loss: 0.4786 - val_accuracy: 0.7842
# Epoch 4/5
# 157/157 [==============================] - 27s 171ms/step - loss: 0.1078 - accuracy: 0.9687 - val_loss: 0.5546 - val_accuracy: 0.7826
# Epoch 5/5
# 157/157 [==============================] - 28s 177ms/step - loss: 0.0394 - accuracy: 0.9916 - val_loss: 0.5656 - val_accuracy: 0.7960

# %%
plt.title('Comparison of Model Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
